# %% [markdown]
# # 🏏 Dallas Bulls Stats
# Use the code cell below to render the Dallas Bulls Stats dashboard with live Google Sheets data.

# %%
from IPython.display import display

# Emits output using the custom mime type registered by this extension.
display({"x-application/dallas-bulls-stats": []}, raw=True)
